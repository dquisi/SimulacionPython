# %% [markdown]
# # Simulacion de eventos discretos del COVID-19
# ## Datos:
# Datos de la provincia de Imbambura:
# Total: 3 hospitales, 11 camas, 11 respiradores, 11 equipos de radiología, personal 150, 1.13% de camas por cada 1000 pesonas.
# - Hospital 1: Camas 7, respiradores 7, 7 equipos de radiologia, 0 ventiladores
# - Hospital 2: Camas 4, respiradores 4, 4 ventiladores
# - Hospital 3: (IESS no se tiene infomacion)
#
# ### Datos estadisticos:
#
# - Tasa de crecimiento: 7 (Modelo de probabilidad)
# - Infectados actuales: 99
#
# ## Modelo Propuesto
#
# Generar un modelo del uso de los recursos de los hospitales para la atencion de las personas que tiene el COVID-19 en base a los datos presentados, por cada uno de los dias.

# %%
import simpy
import random
import matplotlib.pyplot as pp
import numpy as np

# %matplotlib inline


#PARAMETROS
HOSPITALES = 2
HOSPITAL_CAMA_A = 7
HOSPITAL_CAMA_B = 4
HOSPITAL_VENT_A = 7
HOSPITAL_VENT_B = 4
INFECTADOS = 0
TASA_CRECIMIENTO = 7
PERSONAL_MEDICO = 150
DIAS_INTERNADO = 10
DIAS_SIMULACION = 20

#Diccionario para almacenar los resultados
persona_recuperadas={}
persona_fallecidas={}


class Hospital(object):
    #constructor
    def __init__(self, env, num_cama, name):
            self.env = env
            self.num_cama = num_cama
            self.camas = simpy.Resource(env, num_cama)
            self.name = name
            
    def ingresar_paciente(self, paciente):
        yield self.env.timeout(random.randint(DIAS_INTERNADO-5, DIAS_INTERNADO+5))
        print("El paciente se termino de atender: ", paciente, " tiempo de salida: ", self.env.now, " hospital ", self.name)

def llegada_paciente(env, hospital, paciente):
    arrive = env.now
    estado = random.randint(1,100)
    if (estado < 60):
        with hospital.camas.request() as cama:
            dias_esperando = random.randint(1,5) #Numero de dias maximo que puede esperar sin ser asignado a una cama dentro del hospital
            requerimiento = yield cama | env.timeout(dias_esperando)
            wait = env.now - arrive
            if cama in requerimiento:
                print("Al paciente: ", paciente, " se le asigna una CAMA ", " hospital " , hospital.name)
                yield env.process(hospital.ingresar_paciente(paciente))
                estado = random.randint(1,100)
                if (estado < 8) :
                    persona_fallecidas[env.now] = persona_fallecidas[env.now] + 1 if env.now in persona_fallecidas else  1
                else:
                    persona_recuperadas[env.now] = persona_recuperadas[env.now] + 1 if env.now in persona_recuperadas else 1
            else:
                print("El paciente " , paciente, " en el hospital ", hospital.name, " espero ", wait , " fallece no hay camas")
                persona_fallecidas[env.now] = persona_fallecidas[env.now] + 1 if env.now in persona_fallecidas else  1        
    else :
        print("El paciente no tiene COVID : ", paciente, " hospital ", hospital.name )

def ejecutar(env, tasa_crecimiento, infectados):
    hospitalA = Hospital(env, HOSPITAL_CAMA_A, "A")
    hospitalB = Hospital(env, HOSPITAL_CAMA_B, "B")
    for i in range(infectados):
        asignar_hospital(env, hospitalA, hospitalB, i)
    paciente = infectados
    while True:
        yield env.timeout(1)
        for i in range(tasa_crecimiento):
            paciente += 1
            asignar_hospital(env, hospitalA, hospitalB, paciente)
                
def asignar_hospital(env, hospitalA, hospitalB, paciente):
    hosp_esc = random.randint(1,2)
    if (hosp_esc == 1):
        print("Llega paciente nuevo : ", paciente, " hospital A tiempo ", env.now)
        env.process(llegada_paciente(env, hospitalA, paciente))
    else:
        print("Llega paciente nuevo : ", paciente, " hospital B tiempo ", env.now)
        env.process(llegada_paciente(env, hospitalB, paciente))
    
print("Simulacion COVID 19")
env=simpy.Environment()
env.process(ejecutar(env,TASA_CRECIMIENTO, INFECTADOS))
env.run(until=DIAS_SIMULACION)

print("Resultados pacientes :")
print("Recuperados: ")
print(persona_recuperadas)
print("Fallecidos: ")
print(persona_fallecidas)

datos=sorted(persona_recuperadas.items()) # Ordenamos los datos
x, y =zip(*datos) # Obtener x(tiempo - clave) y el y(Numero de vehiculos atendidos - valor)
pp.plot(x,y,linewidth=2,color='red') #Dibujamos las lineas
pp.scatter(x,y,color='blue') # Dibujamos los puntos (x,y)
pp.title("Dias  / Personas Recuperadas")
pp.grid(True) #Generamos una cuadricula
pp.show() #Mostramos el grafico

if (persona_fallecidas):
    datos=sorted(persona_fallecidas.items()) # Ordenamos los datos
    x, y =zip(*datos) # Obtener x(tiempo - clave) y el y(Numero de vehiculos atendidos - valor)
    pp.plot(x,y,linewidth=2,color='red') #Dibujamos las lineas
    pp.scatter(x,y,color='blue') # Dibujamos los puntos (x,y)
    pp.title("Personas Fallecidas  / dias de hospitalizacion")
    pp.grid(True) #Generamos una cuadricula
    pp.show() #Mostramos el grafico
# Out:
# Simulacion COVID 19
# Llega paciente nuevo :  1  hospital B tiempo  1
# Llega paciente nuevo :  2  hospital A tiempo  1
# Llega paciente nuevo :  3  hospital B tiempo  1
# Llega paciente nuevo :  4  hospital A tiempo  1
# Llega paciente nuevo :  5  hospital B tiempo  1
# Llega paciente nuevo :  6  hospital A tiempo  1
# Llega paciente nuevo :  7  hospital B tiempo  1
# El paciente no tiene COVID :  7  hospital  B
# Al paciente:  1  se le asigna una CAMA   hospital  B
# Al paciente:  2  se le asigna una CAMA   hospital  A
# Al paciente:  3  se le asigna una CAMA   hospital  B
# Al paciente:  4  se le asigna una CAMA   hospital  A
# Al paciente:  5  se le asigna una CAMA   hospital  B
# Al paciente:  6  se le asigna una CAMA   hospital  A
# Llega paciente nuevo :  8  hospital B tiempo  2
# Llega paciente nuevo :  9  hospital B tiempo  2
# Llega paciente nuevo :  10  hospital A tiempo  2
# Llega paciente nuevo :  11  hospital B tiempo  2
# Llega paciente nuevo :  12  hospital A tiempo  2
# Llega paciente nuevo :  13  hospital A tiempo  2
# Llega paciente nuevo :  14  hospital A tiempo  2
# El paciente no tiene COVID :  10  hospital  A
# El paciente no tiene COVID :  11  hospital  B
# Al paciente:  8  se le asigna una CAMA   hospital  B
# Al paciente:  12  se le asigna una CAMA   hospital  A
# Al paciente:  13  se le asigna una CAMA   hospital  A
# Al paciente:  14  se le asigna una CAMA   hospital  A
# Llega paciente nuevo :  15  hospital B tiempo  3
# Llega paciente nuevo :  16  hospital A tiempo  3
# Llega paciente nuevo :  17  hospital B tiempo  3
# Llega paciente nuevo :  18  hospital A tiempo  3
# Llega paciente nuevo :  19  hospital A tiempo  3
# Llega paciente nuevo :  20  hospital B tiempo  3
# Llega paciente nuevo :  21  hospital A tiempo  3
# El paciente no tiene COVID :  17  hospital  B
# El paciente no tiene COVID :  18  hospital  A
# Al paciente:  16  se le asigna una CAMA   hospital  A
# Llega paciente nuevo :  22  hospital A tiempo  4
# Llega paciente nuevo :  23  hospital A tiempo  4
# Llega paciente nuevo :  24  hospital A tiempo  4
# Llega paciente nuevo :  25  hospital A tiempo  4
# Llega paciente nuevo :  26  hospital A tiempo  4
# Llega paciente nuevo :  27  hospital A tiempo  4
# Llega paciente nuevo :  28  hospital B tiempo  4
# El paciente no tiene COVID :  22  hospital  A
# El paciente no tiene COVID :  23  hospital  A
# El paciente no tiene COVID :  26  hospital  A
# El paciente  15  en el hospital  B  espero  1.6374991145456796  fallece no hay camas
# El paciente  19  en el hospital  A  espero  1.6491955199255077  fallece no hay camas
# Llega paciente nuevo :  29  hospital A tiempo  5
# Llega paciente nuevo :  30  hospital B tiempo  5
# Llega paciente nuevo :  31  hospital A tiempo  5
# Llega paciente nuevo :  32  hospital B tiempo  5
# Llega paciente nuevo :  33  hospital A tiempo  5
# Llega paciente nuevo :  34  hospital A tiempo  5
# Llega paciente nuevo :  35  hospital A tiempo  5
# El paciente no tiene COVID :  29  hospital  A
# El paciente no tiene COVID :  30  hospital  B
# El paciente no tiene COVID :  31  hospital  A
# El paciente no tiene COVID :  34  hospital  A
# El paciente no tiene COVID :  35  hospital  A
# El paciente  9  en el hospital  B  espero  3.0390453943205227  fallece no hay camas
# El paciente  25  en el hospital  A  espero  1.7778839554194645  fallece no hay camas
# El paciente  21  en el hospital  A  espero  2.7846184943263594  fallece no hay camas
# Llega paciente nuevo :  36  hospital B tiempo  6
# Llega paciente nuevo :  37  hospital A tiempo  6
# Llega paciente nuevo :  38  hospital B tiempo  6
# Llega paciente nuevo :  39  hospital A tiempo  6
# Llega paciente nuevo :  40  hospital A tiempo  6
# Llega paciente nuevo :  41  hospital B tiempo  6
# Llega paciente nuevo :  42  hospital B tiempo  6
# El paciente no tiene COVID :  36  hospital  B
# El paciente no tiene COVID :  37  hospital  A
# El paciente no tiene COVID :  38  hospital  B
# El paciente  27  en el hospital  A  espero  2.384574671439003  fallece no hay camas
# El paciente se termino de atender:  4  tiempo de salida:  7  hospital  A
# El paciente se termino de atender:  6  tiempo de salida:  7  hospital  A
# Llega paciente nuevo :  43  hospital B tiempo  7
# Llega paciente nuevo :  44  hospital A tiempo  7
# Llega paciente nuevo :  45  hospital A tiempo  7
# Llega paciente nuevo :  46  hospital A tiempo  7
# Llega paciente nuevo :  47  hospital B tiempo  7
# Llega paciente nuevo :  48  hospital A tiempo  7
# Llega paciente nuevo :  49  hospital A tiempo  7
# El paciente no tiene COVID :  45  hospital  A
# Al paciente:  24  se le asigna una CAMA   hospital  A
# Al paciente:  33  se le asigna una CAMA   hospital  A
# El paciente  40  en el hospital  A  espero  1.1282567116207627  fallece no hay camas
# El paciente  20  en el hospital  B  espero  4.622077063493884  fallece no hay camas
# El paciente  32  en el hospital  B  espero  2.978594594507986  fallece no hay camas
# El paciente se termino de atender:  2  tiempo de salida:  8  hospital  A
# El paciente se termino de atender:  3  tiempo de salida:  8  hospital  B
# Llega paciente nuevo :  50  hospital A tiempo  8
# Llega paciente nuevo :  51  hospital A tiempo  8
# Llega paciente nuevo :  52  hospital B tiempo  8
# Llega paciente nuevo :  53  hospital B tiempo  8
# Llega paciente nuevo :  54  hospital A tiempo  8
# Llega paciente nuevo :  55  hospital B tiempo  8
# Llega paciente nuevo :  56  hospital B tiempo  8
# El paciente no tiene COVID :  56  hospital  B
# Al paciente:  39  se le asigna una CAMA   hospital  A
# Al paciente:  28  se le asigna una CAMA   hospital  B
# El paciente  41  en el hospital  B  espero  2.963411782031491  fallece no hay camas
# El paciente se termino de atender:  12  tiempo de salida:  9  hospital  A
# Llega paciente nuevo :  57  hospital B tiempo  9
# Llega paciente nuevo :  58  hospital A tiempo  9
# Llega paciente nuevo :  59  hospital A tiempo  9
# Llega paciente nuevo :  60  hospital B tiempo  9
# Llega paciente nuevo :  61  hospital B tiempo  9
# Llega paciente nuevo :  62  hospital A tiempo  9
# Llega paciente nuevo :  63  hospital A tiempo  9
# El paciente no tiene COVID :  59  hospital  A
# El paciente no tiene COVID :  62  hospital  A
# El paciente no tiene COVID :  63  hospital  A
# Al paciente:  44  se le asigna una CAMA   hospital  A
# El paciente  46  en el hospital  A  espero  2.1266953391445753  fallece no hay camas
# El paciente  53  en el hospital  B  espero  1.156669331141135  fallece no hay camas
# El paciente  51  en el hospital  A  espero  1.689769684417076  fallece no hay camas
# Llega paciente nuevo :  64  hospital B tiempo  10
# Llega paciente nuevo :  65  hospital A tiempo  10
# Llega paciente nuevo :  66  hospital A tiempo  10
# Llega paciente nuevo :  67  hospital B tiempo  10
# Llega paciente nuevo :  68  hospital A tiempo  10
# Llega paciente nuevo :  69  hospital A tiempo  10
# Llega paciente nuevo :  70  hospital A tiempo  10
# El paciente no tiene COVID :  66  hospital  A
# El paciente no tiene COVID :  67  hospital  B
# El paciente no tiene COVID :  70  hospital  A
# El paciente  48  en el hospital  A  espero  3.2667824716505134  fallece no hay camas
# El paciente  54  en el hospital  A  espero  2.3553130365266277  fallece no hay camas
# El paciente  55  en el hospital  B  espero  2.4664392056886086  fallece no hay camas
# El paciente  49  en el hospital  A  espero  3.4899456120065278  fallece no hay camas
# El paciente  42  en el hospital  B  espero  4.702901757559969  fallece no hay camas
# El paciente  57  en el hospital  B  espero  1.7595067869119028  fallece no hay camas
# El paciente  52  en el hospital  B  espero  2.8000417020903363  fallece no hay camas
# El paciente se termino de atender:  8  tiempo de salida:  11  hospital  B
# El paciente se termino de atender:  14  tiempo de salida:  11  hospital  A
# Llega paciente nuevo :  71  hospital A tiempo  11
# Llega paciente nuevo :  72  hospital A tiempo  11
# Llega paciente nuevo :  73  hospital B tiempo  11
# Llega paciente nuevo :  74  hospital B tiempo  11
# Llega paciente nuevo :  75  hospital A tiempo  11
# Llega paciente nuevo :  76  hospital B tiempo  11
# Llega paciente nuevo :  77  hospital A tiempo  11
# El paciente no tiene COVID :  72  hospital  A
# El paciente no tiene COVID :  73  hospital  B
# El paciente no tiene COVID :  75  hospital  A
# Al paciente:  43  se le asigna una CAMA   hospital  B
# Al paciente:  50  se le asigna una CAMA   hospital  A
# El paciente  47  en el hospital  B  espero  4.411277990207342  fallece no hay camas
# El paciente  60  en el hospital  B  espero  2.9602856499070693  fallece no hay camas
# El paciente se termino de atender:  5  tiempo de salida:  12  hospital  B
# Llega paciente nuevo :  78  hospital A tiempo  12
# Llega paciente nuevo :  79  hospital B tiempo  12
# Llega paciente nuevo :  80  hospital B tiempo  12
# Llega paciente nuevo :  81  hospital A tiempo  12
# Llega paciente nuevo :  82  hospital B tiempo  12
# Llega paciente nuevo :  83  hospital B tiempo  12
# Llega paciente nuevo :  84  hospital A tiempo  12
# El paciente no tiene COVID :  78  hospital  A
# El paciente no tiene COVID :  82  hospital  B
# El paciente no tiene COVID :  84  hospital  A
# Al paciente:  61  se le asigna una CAMA   hospital  B
# El paciente  58  en el hospital  A  espero  3.7765108088066466  fallece no hay camas
# El paciente  69  en el hospital  A  espero  2.981627397335952  fallece no hay camas
# El paciente se termino de atender:  13  tiempo de salida:  13  hospital  A
# Llega paciente nuevo :  85  hospital B tiempo  13
# Llega paciente nuevo :  86  hospital A tiempo  13
# Llega paciente nuevo :  87  hospital B tiempo  13
# Llega paciente nuevo :  88  hospital B tiempo  13
# Llega paciente nuevo :  89  hospital B tiempo  13
# Llega paciente nuevo :  90  hospital A tiempo  13
# Llega paciente nuevo :  91  hospital B tiempo  13
# El paciente no tiene COVID :  86  hospital  A
# El paciente no tiene COVID :  87  hospital  B
# El paciente no tiene COVID :  88  hospital  B
# El paciente no tiene COVID :  91  hospital  B
# Al paciente:  65  se le asigna una CAMA   hospital  A
# El paciente  76  en el hospital  B  espero  2.8408952528743914  fallece no hay camas
# Llega paciente nuevo :  92  hospital B tiempo  14
# Llega paciente nuevo :  93  hospital B tiempo  14
# Llega paciente nuevo :  94  hospital A tiempo  14
# Llega paciente nuevo :  95  hospital A tiempo  14
# Llega paciente nuevo :  96  hospital B tiempo  14
# Llega paciente nuevo :  97  hospital A tiempo  14
# Llega paciente nuevo :  98  hospital B tiempo  14
# El paciente no tiene COVID :  94  hospital  A
# El paciente  71  en el hospital  A  espero  3.134316914275246  fallece no hay camas
# El paciente  90  en el hospital  A  espero  1.1488414434650611  fallece no hay camas
# El paciente  77  en el hospital  A  espero  3.276065626921067  fallece no hay camas
# El paciente  81  en el hospital  A  espero  2.523874210723971  fallece no hay camas
# El paciente  68  en el hospital  A  espero  4.552228996894744  fallece no hay camas
# El paciente  64  en el hospital  B  espero  4.65814424567551  fallece no hay camas
# El paciente se termino de atender:  1  tiempo de salida:  15  hospital  B
# El paciente se termino de atender:  24  tiempo de salida:  15  hospital  A
# El paciente se termino de atender:  28  tiempo de salida:  15  hospital  B
# Llega paciente nuevo :  99  hospital A tiempo  15
# Llega paciente nuevo :  100  hospital B tiempo  15
# Llega paciente nuevo :  101  hospital A tiempo  15
# Llega paciente nuevo :  102  hospital B tiempo  15
# Llega paciente nuevo :  103  hospital B tiempo  15
# Llega paciente nuevo :  104  hospital A tiempo  15
# Llega paciente nuevo :  105  hospital A tiempo  15
# El paciente no tiene COVID :  99  hospital  A
# El paciente no tiene COVID :  101  hospital  A
# El paciente no tiene COVID :  105  hospital  A
# Al paciente:  74  se le asigna una CAMA   hospital  B
# Al paciente:  95  se le asigna una CAMA   hospital  A
# Al paciente:  79  se le asigna una CAMA   hospital  B
# El paciente  85  en el hospital  B  espero  2.0245438063534724  fallece no hay camas
# El paciente se termino de atender:  16  tiempo de salida:  16  hospital  A
# Llega paciente nuevo :  106  hospital B tiempo  16
# Llega paciente nuevo :  107  hospital A tiempo  16
# Llega paciente nuevo :  108  hospital B tiempo  16
# Llega paciente nuevo :  109  hospital A tiempo  16
# Llega paciente nuevo :  110  hospital A tiempo  16
# Llega paciente nuevo :  111  hospital A tiempo  16
# Llega paciente nuevo :  112  hospital A tiempo  16
# El paciente no tiene COVID :  106  hospital  B
# El paciente no tiene COVID :  109  hospital  A
# El paciente no tiene COVID :  111  hospital  A
# El paciente no tiene COVID :  112  hospital  A
# Al paciente:  97  se le asigna una CAMA   hospital  A
# El paciente  83  en el hospital  B  espero  4.182973366449435  fallece no hay camas
# El paciente  93  en el hospital  B  espero  2.219736961788602  fallece no hay camas
# El paciente  89  en el hospital  B  espero  3.6251928184596025  fallece no hay camas
# El paciente  80  en el hospital  B  espero  4.6868747687218075  fallece no hay camas
# El paciente se termino de atender:  33  tiempo de salida:  17  hospital  A
# Llega paciente nuevo :  113  hospital A tiempo  17
# Llega paciente nuevo :  114  hospital B tiempo  17
# Llega paciente nuevo :  115  hospital A tiempo  17
# Llega paciente nuevo :  116  hospital A tiempo  17
# Llega paciente nuevo :  117  hospital A tiempo  17
# Llega paciente nuevo :  118  hospital B tiempo  17
# Llega paciente nuevo :  119  hospital B tiempo  17
# El paciente no tiene COVID :  113  hospital  A
# El paciente no tiene COVID :  117  hospital  A
# El paciente no tiene COVID :  118  hospital  B
# Al paciente:  104  se le asigna una CAMA   hospital  A
# El paciente  102  en el hospital  B  espero  2.3424327548496287  fallece no hay camas
# El paciente  107  en el hospital  A  espero  1.5125903366111544  fallece no hay camas
# El paciente  103  en el hospital  B  espero  2.578785161132906  fallece no hay camas
# Llega paciente nuevo :  120  hospital B tiempo  18
# Llega paciente nuevo :  121  hospital A tiempo  18
# Llega paciente nuevo :  122  hospital A tiempo  18
# Llega paciente nuevo :  123  hospital B tiempo  18
# Llega paciente nuevo :  124  hospital A tiempo  18
# Llega paciente nuevo :  125  hospital A tiempo  18
# Llega paciente nuevo :  126  hospital B tiempo  18
# El paciente no tiene COVID :  121  hospital  A
# El paciente no tiene COVID :  122  hospital  A
# El paciente no tiene COVID :  126  hospital  B
# El paciente  98  en el hospital  B  espero  4.208816175516493  fallece no hay camas
# El paciente  96  en el hospital  B  espero  4.378653392605209  fallece no hay camas
# El paciente  110  en el hospital  A  espero  2.443037350189737  fallece no hay camas
# El paciente  92  en el hospital  B  espero  4.6103402063375825  fallece no hay camas
# Llega paciente nuevo :  127  hospital A tiempo  19
# Llega paciente nuevo :  128  hospital A tiempo  19
# Llega paciente nuevo :  129  hospital A tiempo  19
# Llega paciente nuevo :  130  hospital A tiempo  19
# Llega paciente nuevo :  131  hospital B tiempo  19
# Llega paciente nuevo :  132  hospital A tiempo  19
# Llega paciente nuevo :  133  hospital A tiempo  19
# El paciente no tiene COVID :  127  hospital  A
# El paciente no tiene COVID :  129  hospital  A
# El paciente  100  en el hospital  B  espero  4.0704747980989495  fallece no hay camas
# El paciente  124  en el hospital  A  espero  1.1672409594955226  fallece no hay camas
# El paciente  114  en el hospital  B  espero  2.445087483777197  fallece no hay camas
# Resultados pacientes :
# Recuperados:
# {7: 2, 8: 2, 9: 1, 11: 2, 12: 1, 15: 3, 16: 1, 17: 1}
# Fallecidos:
# {4.63749911454568: 1, 4.649195519925508: 1, 5.039045394320523: 1, 5.7778839554194645: 1, 5.784618494326359: 1, 6.384574671439003: 1, 7.128256711620763: 1, 7.622077063493884: 1, 7.978594594507986: 1, 8.963411782031491: 1, 9.126695339144575: 1, 9.156669331141135: 1, 9.689769684417076: 1, 10.266782471650513: 1, 10.355313036526628: 1, 10.466439205688609: 1, 10.489945612006528: 1, 10.70290175755997: 1, 10.759506786911903: 1, 10.800041702090336: 1, 11.411277990207342: 1, 11.96028564990707: 1, 12.776510808806647: 1, 12.981627397335952: 1, 13: 1, 13.840895252874391: 1, 14.134316914275246: 1, 14.148841443465061: 1, 14.276065626921067: 1, 14.523874210723971: 1, 14.552228996894744: 1, 14.65814424567551: 1, 15.024543806353472: 1, 16.182973366449435: 1, 16.219736961788602: 1, 16.625192818459603: 1, 16.686874768721808: 1, 17.34243275484963: 1, 17.512590336611154: 1, 17.578785161132906: 1, 18.208816175516493: 1, 18.37865339260521: 1, 18.443037350189737: 1, 18.610340206337582: 1, 19.07047479809895: 1, 19.167240959495523: 1, 19.445087483777197: 1}
