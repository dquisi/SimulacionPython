# %% [markdown]
# # Simulacion de eventos discretos del COVID-19
# ## Datos:
# Datos de la provincia de Imbambura:
# Total: 3 hospitales, 11 camas, 11 respiradores, 11 equipos de radiología, personal 150, 1.13% de camas por cada 1000 pesonas.
# - Hospital 1: Camas 7, respiradores 7, 7 equipos de radiologia, 0 ventiladores
# - Hospital 2: Camas 4, respiradores 4, 4 ventiladores
# - Hospital 3: (IESS no se tiene infomacion)
#
# ### Datos estadisticos:
#
# - Tasa de crecimiento: 7 (Modelo de probabilidad)
# - Infectados actuales: 99
#
# ## Modelo Propuesto
#
# Generar un modelo del uso de los recursos de los hospitales para la atencion de las personas que tiene el COVID-19 en base a los datos presentados, por cada uno de los dias.

# %%
import simpy
import random
import matplotlib.pyplot as pp
import numpy as np

# %matplotlib inline


#PARAMETROS
HOSPITALES = 2
HOSPITAL_CAMA_A = 7
HOSPITAL_CAMA_B = 4
HOSPITAL_VENT_A = 7
HOSPITAL_VENT_B = 4
INFECTADOS = 20
TASA_CRECIMIENTO = 7
PERSONAL_MEDICO = 150
DIAS_INTERNADO = 10
DIAS_SIMULACION = 20

#Diccionario para almacenar los resultados
persona_recuperadas={}
persona_fallecidas={}


class Hospital(object):
    #constructor
    def __init__(self, env, num_cama, name):
            self.env = env
            self.num_cama = num_cama
            self.camas = simpy.Resource(env, num_cama)
            self.name = name
            
    def ingresar_paciente(self, paciente):
        yield self.env.timeout(random.randint(DIAS_INTERNADO-5, DIAS_INTERNADO+5))
        print("El paciente se termino de atender: ", paciente, " tiempo de salida: ", self.env.now, " hospital ", self.name)

def llegada_paciente(env, hospital, paciente):
    arrive = env.now
    estado = random.randint(1,100)
    if (estado < 60):
        with hospital.camas.request() as cama:
            dias_esperando = random.randint(1,5) #Numero de dias maximo que puede esperar sin ser asignado a una cama dentro del hospital
            requerimiento = yield cama | env.timeout(dias_esperando)
            wait = env.now - arrive
            if cama in requerimiento:
                print("Al paciente: ", paciente, " se le asigna una CAMA ", " hospital " , hospital.name)
                yield env.process(hospital.ingresar_paciente(paciente))
                estado = random.randint(1,100)
                if (estado < 8) :
                    persona_fallecidas[env.now] = persona_fallecidas[env.now] + 1 if env.now in persona_fallecidas else  1
                else:
                    persona_recuperadas[env.now] = persona_recuperadas[env.now] + 1 if env.now in persona_recuperadas else 1
            else:
                print("El paciente " , paciente, " en el hospital ", hospital.name, " espero ", wait , " dias y fallece no hay camas")
                persona_fallecidas[env.now] = persona_fallecidas[env.now] + 1 if env.now in persona_fallecidas else  1        
    else :
        print("El paciente no tiene COVID : ", paciente, " hospital ", hospital.name )

def ejecutar(env, tasa_crecimiento, infectados):
    hospitalA = Hospital(env, HOSPITAL_CAMA_A, "A")
    hospitalB = Hospital(env, HOSPITAL_CAMA_B, "B")
    for i in range(infectados):
        asignar_hospital(env, hospitalA, hospitalB, i)
    paciente = infectados
    while True:
        yield env.timeout(1)
        for i in range(tasa_crecimiento):
            paciente += 1
            asignar_hospital(env, hospitalA, hospitalB, paciente)
                
def asignar_hospital(env, hospitalA, hospitalB, paciente):
    hosp_esc = random.randint(1,2)
    if (hosp_esc == 1):
        print("Llega paciente nuevo : ", paciente, " hospital A tiempo ", env.now)
        env.process(llegada_paciente(env, hospitalA, paciente))
    else:
        print("Llega paciente nuevo : ", paciente, " hospital B tiempo ", env.now)
        env.process(llegada_paciente(env, hospitalB, paciente))
    
print("Simulacion COVID 19")
env=simpy.Environment()
env.process(ejecutar(env,TASA_CRECIMIENTO, INFECTADOS))
env.run(until=DIAS_SIMULACION)

print("Resultados pacientes :")
print("Recuperados: ")
print(persona_recuperadas)
print("Fallecidos: ")
print(persona_fallecidas)

datos=sorted(persona_recuperadas.items()) # Ordenamos los datos
x, y =zip(*datos) # Obtener x(tiempo - clave) y el y(Numero de vehiculos atendidos - valor)
pp.plot(x,y,linewidth=2,color='red') #Dibujamos las lineas
pp.scatter(x,y,color='blue') # Dibujamos los puntos (x,y)
pp.title("Dias  / Personas Recuperadas")
pp.grid(True) #Generamos una cuadricula
pp.show() #Mostramos el grafico

if (persona_fallecidas):
    datos=sorted(persona_fallecidas.items()) # Ordenamos los datos
    x, y =zip(*datos) # Obtener x(tiempo - clave) y el y(Numero de vehiculos atendidos - valor)
    pp.plot(x,y,linewidth=2,color='red') #Dibujamos las lineas
    pp.scatter(x,y,color='blue') # Dibujamos los puntos (x,y)
    pp.title("Personas Fallecidas  / dias de hospitalizacion")
    pp.grid(True) #Generamos una cuadricula
    pp.show() #Mostramos el grafico
# Out:
# Simulacion COVID 19
# Llega paciente nuevo :  0  hospital A tiempo  0
# Llega paciente nuevo :  1  hospital A tiempo  0
# Llega paciente nuevo :  2  hospital A tiempo  0
# Llega paciente nuevo :  3  hospital B tiempo  0
# Llega paciente nuevo :  4  hospital B tiempo  0
# Llega paciente nuevo :  5  hospital A tiempo  0
# Llega paciente nuevo :  6  hospital A tiempo  0
# Llega paciente nuevo :  7  hospital B tiempo  0
# Llega paciente nuevo :  8  hospital A tiempo  0
# Llega paciente nuevo :  9  hospital A tiempo  0
# Llega paciente nuevo :  10  hospital A tiempo  0
# Llega paciente nuevo :  11  hospital B tiempo  0
# Llega paciente nuevo :  12  hospital B tiempo  0
# Llega paciente nuevo :  13  hospital A tiempo  0
# Llega paciente nuevo :  14  hospital B tiempo  0
# Llega paciente nuevo :  15  hospital B tiempo  0
# Llega paciente nuevo :  16  hospital B tiempo  0
# Llega paciente nuevo :  17  hospital B tiempo  0
# Llega paciente nuevo :  18  hospital B tiempo  0
# Llega paciente nuevo :  19  hospital B tiempo  0
# El paciente no tiene COVID :  1  hospital  A
# El paciente no tiene COVID :  4  hospital  B
# El paciente no tiene COVID :  6  hospital  A
# El paciente no tiene COVID :  7  hospital  B
# El paciente no tiene COVID :  11  hospital  B
# El paciente no tiene COVID :  14  hospital  B
# El paciente no tiene COVID :  19  hospital  B
# Al paciente:  0  se le asigna una CAMA   hospital  A
# Al paciente:  2  se le asigna una CAMA   hospital  A
# Al paciente:  3  se le asigna una CAMA   hospital  B
# Al paciente:  5  se le asigna una CAMA   hospital  A
# Al paciente:  8  se le asigna una CAMA   hospital  A
# Al paciente:  9  se le asigna una CAMA   hospital  A
# Al paciente:  10  se le asigna una CAMA   hospital  A
# Al paciente:  12  se le asigna una CAMA   hospital  B
# Al paciente:  13  se le asigna una CAMA   hospital  A
# Al paciente:  15  se le asigna una CAMA   hospital  B
# Al paciente:  16  se le asigna una CAMA   hospital  B
# Llega paciente nuevo :  21  hospital B tiempo  1
# Llega paciente nuevo :  22  hospital A tiempo  1
# Llega paciente nuevo :  23  hospital B tiempo  1
# Llega paciente nuevo :  24  hospital A tiempo  1
# Llega paciente nuevo :  25  hospital A tiempo  1
# Llega paciente nuevo :  26  hospital B tiempo  1
# Llega paciente nuevo :  27  hospital B tiempo  1
# El paciente no tiene COVID :  21  hospital  B
# El paciente no tiene COVID :  22  hospital  A
# El paciente no tiene COVID :  24  hospital  A
# El paciente no tiene COVID :  27  hospital  B
# Llega paciente nuevo :  28  hospital B tiempo  2
# Llega paciente nuevo :  29  hospital A tiempo  2
# Llega paciente nuevo :  30  hospital A tiempo  2
# Llega paciente nuevo :  31  hospital B tiempo  2
# Llega paciente nuevo :  32  hospital A tiempo  2
# Llega paciente nuevo :  33  hospital A tiempo  2
# Llega paciente nuevo :  34  hospital A tiempo  2
# El paciente no tiene COVID :  29  hospital  A
# El paciente no tiene COVID :  31  hospital  B
# El paciente no tiene COVID :  32  hospital  A
# El paciente no tiene COVID :  33  hospital  A
# El paciente  17  en el hospital  B  espero  2  dias y fallece no hay camas
# Llega paciente nuevo :  35  hospital B tiempo  3
# Llega paciente nuevo :  36  hospital A tiempo  3
# Llega paciente nuevo :  37  hospital A tiempo  3
# Llega paciente nuevo :  38  hospital A tiempo  3
# Llega paciente nuevo :  39  hospital A tiempo  3
# Llega paciente nuevo :  40  hospital B tiempo  3
# Llega paciente nuevo :  41  hospital B tiempo  3
# El paciente no tiene COVID :  41  hospital  B
# El paciente  25  en el hospital  A  espero  2  dias y fallece no hay camas
# Llega paciente nuevo :  42  hospital B tiempo  4
# Llega paciente nuevo :  43  hospital A tiempo  4
# Llega paciente nuevo :  44  hospital A tiempo  4
# Llega paciente nuevo :  45  hospital A tiempo  4
# Llega paciente nuevo :  46  hospital B tiempo  4
# Llega paciente nuevo :  47  hospital B tiempo  4
# Llega paciente nuevo :  48  hospital B tiempo  4
# El paciente no tiene COVID :  42  hospital  B
# El paciente no tiene COVID :  43  hospital  A
# El paciente no tiene COVID :  44  hospital  A
# El paciente no tiene COVID :  48  hospital  B
# El paciente  18  en el hospital  B  espero  4  dias y fallece no hay camas
# El paciente  39  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente se termino de atender:  9  tiempo de salida:  5  hospital  A
# Llega paciente nuevo :  49  hospital B tiempo  5
# Llega paciente nuevo :  50  hospital B tiempo  5
# Llega paciente nuevo :  51  hospital A tiempo  5
# Llega paciente nuevo :  52  hospital A tiempo  5
# Llega paciente nuevo :  53  hospital B tiempo  5
# Llega paciente nuevo :  54  hospital B tiempo  5
# Llega paciente nuevo :  55  hospital B tiempo  5
# El paciente no tiene COVID :  49  hospital  B
# El paciente no tiene COVID :  51  hospital  A
# El paciente no tiene COVID :  52  hospital  A
# El paciente  26  en el hospital  B  espero  4  dias y fallece no hay camas
# El paciente  28  en el hospital  B  espero  3  dias y fallece no hay camas
# El paciente  35  en el hospital  B  espero  2  dias y fallece no hay camas
# El paciente  38  en el hospital  A  espero  2  dias y fallece no hay camas
# El paciente  40  en el hospital  B  espero  2  dias y fallece no hay camas
# El paciente  45  en el hospital  A  espero  1  dias y fallece no hay camas
# Al paciente:  30  se le asigna una CAMA   hospital  A
# El paciente se termino de atender:  8  tiempo de salida:  6  hospital  A
# El paciente se termino de atender:  16  tiempo de salida:  6  hospital  B
# Llega paciente nuevo :  56  hospital A tiempo  6
# Llega paciente nuevo :  57  hospital A tiempo  6
# Llega paciente nuevo :  58  hospital A tiempo  6
# Llega paciente nuevo :  59  hospital A tiempo  6
# Llega paciente nuevo :  60  hospital A tiempo  6
# Llega paciente nuevo :  61  hospital A tiempo  6
# Llega paciente nuevo :  62  hospital B tiempo  6
# El paciente no tiene COVID :  56  hospital  A
# El paciente no tiene COVID :  57  hospital  A
# El paciente no tiene COVID :  59  hospital  A
# El paciente no tiene COVID :  60  hospital  A
# El paciente no tiene COVID :  61  hospital  A
# El paciente no tiene COVID :  62  hospital  B
# El paciente  23  en el hospital  B  espero  5  dias y fallece no hay camas
# El paciente  34  en el hospital  A  espero  4  dias y fallece no hay camas
# El paciente  36  en el hospital  A  espero  3  dias y fallece no hay camas
# El paciente  55  en el hospital  B  espero  1  dias y fallece no hay camas
# Al paciente:  37  se le asigna una CAMA   hospital  A
# Al paciente:  46  se le asigna una CAMA   hospital  B
# Llega paciente nuevo :  63  hospital A tiempo  7
# Llega paciente nuevo :  64  hospital B tiempo  7
# Llega paciente nuevo :  65  hospital B tiempo  7
# Llega paciente nuevo :  66  hospital A tiempo  7
# Llega paciente nuevo :  67  hospital B tiempo  7
# Llega paciente nuevo :  68  hospital A tiempo  7
# Llega paciente nuevo :  69  hospital A tiempo  7
# El paciente no tiene COVID :  63  hospital  A
# El paciente no tiene COVID :  66  hospital  A
# El paciente  58  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente se termino de atender:  5  tiempo de salida:  8  hospital  A
# Llega paciente nuevo :  70  hospital A tiempo  8
# Llega paciente nuevo :  71  hospital A tiempo  8
# Llega paciente nuevo :  72  hospital B tiempo  8
# Llega paciente nuevo :  73  hospital A tiempo  8
# Llega paciente nuevo :  74  hospital B tiempo  8
# Llega paciente nuevo :  75  hospital A tiempo  8
# Llega paciente nuevo :  76  hospital B tiempo  8
# El paciente no tiene COVID :  70  hospital  A
# El paciente no tiene COVID :  71  hospital  A
# El paciente no tiene COVID :  72  hospital  B
# El paciente no tiene COVID :  74  hospital  B
# El paciente  50  en el hospital  B  espero  3  dias y fallece no hay camas
# El paciente  68  en el hospital  A  espero  1  dias y fallece no hay camas
# Al paciente:  69  se le asigna una CAMA   hospital  A
# El paciente se termino de atender:  0  tiempo de salida:  9  hospital  A
# Llega paciente nuevo :  77  hospital A tiempo  9
# Llega paciente nuevo :  78  hospital B tiempo  9
# Llega paciente nuevo :  79  hospital A tiempo  9
# Llega paciente nuevo :  80  hospital B tiempo  9
# Llega paciente nuevo :  81  hospital A tiempo  9
# Llega paciente nuevo :  82  hospital A tiempo  9
# Llega paciente nuevo :  83  hospital B tiempo  9
# El paciente no tiene COVID :  78  hospital  B
# El paciente no tiene COVID :  81  hospital  A
# El paciente no tiene COVID :  82  hospital  A
# El paciente  47  en el hospital  B  espero  5  dias y fallece no hay camas
# El paciente  53  en el hospital  B  espero  4  dias y fallece no hay camas
# El paciente  54  en el hospital  B  espero  4  dias y fallece no hay camas
# El paciente  67  en el hospital  B  espero  2  dias y fallece no hay camas
# Al paciente:  73  se le asigna una CAMA   hospital  A
# El paciente se termino de atender:  10  tiempo de salida:  10  hospital  A
# El paciente se termino de atender:  13  tiempo de salida:  10  hospital  A
# Llega paciente nuevo :  84  hospital B tiempo  10
# Llega paciente nuevo :  85  hospital A tiempo  10
# Llega paciente nuevo :  86  hospital A tiempo  10
# Llega paciente nuevo :  87  hospital A tiempo  10
# Llega paciente nuevo :  88  hospital A tiempo  10
# Llega paciente nuevo :  89  hospital B tiempo  10
# Llega paciente nuevo :  90  hospital A tiempo  10
# El paciente no tiene COVID :  84  hospital  B
# El paciente no tiene COVID :  86  hospital  A
# El paciente no tiene COVID :  89  hospital  B
# El paciente  64  en el hospital  B  espero  3  dias y fallece no hay camas
# El paciente  77  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  79  en el hospital  A  espero  1  dias y fallece no hay camas
# Al paciente:  75  se le asigna una CAMA   hospital  A
# Al paciente:  85  se le asigna una CAMA   hospital  A
# El paciente se termino de atender:  30  tiempo de salida:  11  hospital  A
# El paciente se termino de atender:  37  tiempo de salida:  11  hospital  A
# Llega paciente nuevo :  91  hospital B tiempo  11
# Llega paciente nuevo :  92  hospital B tiempo  11
# Llega paciente nuevo :  93  hospital B tiempo  11
# Llega paciente nuevo :  94  hospital A tiempo  11
# Llega paciente nuevo :  95  hospital B tiempo  11
# Llega paciente nuevo :  96  hospital A tiempo  11
# Llega paciente nuevo :  97  hospital A tiempo  11
# El paciente no tiene COVID :  93  hospital  B
# El paciente no tiene COVID :  94  hospital  A
# El paciente no tiene COVID :  96  hospital  A
# Al paciente:  87  se le asigna una CAMA   hospital  A
# Al paciente:  88  se le asigna una CAMA   hospital  A
# El paciente se termino de atender:  12  tiempo de salida:  12  hospital  B
# Llega paciente nuevo :  98  hospital B tiempo  12
# Llega paciente nuevo :  99  hospital A tiempo  12
# Llega paciente nuevo :  100  hospital B tiempo  12
# Llega paciente nuevo :  101  hospital B tiempo  12
# Llega paciente nuevo :  102  hospital B tiempo  12
# Llega paciente nuevo :  103  hospital B tiempo  12
# Llega paciente nuevo :  104  hospital A tiempo  12
# El paciente no tiene COVID :  98  hospital  B
# El paciente no tiene COVID :  100  hospital  B
# El paciente no tiene COVID :  104  hospital  A
# El paciente  65  en el hospital  B  espero  5  dias y fallece no hay camas
# El paciente  76  en el hospital  B  espero  4  dias y fallece no hay camas
# El paciente  90  en el hospital  A  espero  2  dias y fallece no hay camas
# El paciente  91  en el hospital  B  espero  1  dias y fallece no hay camas
# Al paciente:  80  se le asigna una CAMA   hospital  B
# El paciente se termino de atender:  2  tiempo de salida:  13  hospital  A
# El paciente se termino de atender:  15  tiempo de salida:  13  hospital  B
# Llega paciente nuevo :  105  hospital A tiempo  13
# Llega paciente nuevo :  106  hospital A tiempo  13
# Llega paciente nuevo :  107  hospital A tiempo  13
# Llega paciente nuevo :  108  hospital A tiempo  13
# Llega paciente nuevo :  109  hospital B tiempo  13
# Llega paciente nuevo :  110  hospital B tiempo  13
# Llega paciente nuevo :  111  hospital A tiempo  13
# El paciente no tiene COVID :  109  hospital  B
# El paciente no tiene COVID :  110  hospital  B
# El paciente  97  en el hospital  A  espero  2  dias y fallece no hay camas
# El paciente  101  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  103  en el hospital  B  espero  1  dias y fallece no hay camas
# Al paciente:  99  se le asigna una CAMA   hospital  A
# Al paciente:  83  se le asigna una CAMA   hospital  B
# El paciente se termino de atender:  3  tiempo de salida:  14  hospital  B
# El paciente se termino de atender:  73  tiempo de salida:  14  hospital  A
# Llega paciente nuevo :  112  hospital A tiempo  14
# Llega paciente nuevo :  113  hospital A tiempo  14
# Llega paciente nuevo :  114  hospital A tiempo  14
# Llega paciente nuevo :  115  hospital B tiempo  14
# Llega paciente nuevo :  116  hospital B tiempo  14
# Llega paciente nuevo :  117  hospital A tiempo  14
# Llega paciente nuevo :  118  hospital B tiempo  14
# El paciente no tiene COVID :  112  hospital  A
# El paciente  92  en el hospital  B  espero  3  dias y fallece no hay camas
# El paciente  95  en el hospital  B  espero  3  dias y fallece no hay camas
# El paciente  108  en el hospital  A  espero  1  dias y fallece no hay camas
# Al paciente:  102  se le asigna una CAMA   hospital  B
# Al paciente:  105  se le asigna una CAMA   hospital  A
# Llega paciente nuevo :  119  hospital A tiempo  15
# Llega paciente nuevo :  120  hospital A tiempo  15
# Llega paciente nuevo :  121  hospital A tiempo  15
# Llega paciente nuevo :  122  hospital A tiempo  15
# Llega paciente nuevo :  123  hospital A tiempo  15
# Llega paciente nuevo :  124  hospital B tiempo  15
# Llega paciente nuevo :  125  hospital A tiempo  15
# El paciente no tiene COVID :  125  hospital  A
# El paciente  107  en el hospital  A  espero  2  dias y fallece no hay camas
# El paciente  111  en el hospital  A  espero  2  dias y fallece no hay camas
# El paciente  115  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  116  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente se termino de atender:  46  tiempo de salida:  16  hospital  B
# Llega paciente nuevo :  126  hospital A tiempo  16
# Llega paciente nuevo :  127  hospital B tiempo  16
# Llega paciente nuevo :  128  hospital B tiempo  16
# Llega paciente nuevo :  129  hospital A tiempo  16
# Llega paciente nuevo :  130  hospital B tiempo  16
# Llega paciente nuevo :  131  hospital B tiempo  16
# Llega paciente nuevo :  132  hospital B tiempo  16
# El paciente no tiene COVID :  130  hospital  B
# El paciente no tiene COVID :  132  hospital  B
# El paciente  117  en el hospital  A  espero  2  dias y fallece no hay camas
# El paciente  120  en el hospital  A  espero  1  dias y fallece no hay camas
# Al paciente:  118  se le asigna una CAMA   hospital  B
# Llega paciente nuevo :  133  hospital B tiempo  17
# Llega paciente nuevo :  134  hospital B tiempo  17
# Llega paciente nuevo :  135  hospital A tiempo  17
# Llega paciente nuevo :  136  hospital B tiempo  17
# Llega paciente nuevo :  137  hospital B tiempo  17
# Llega paciente nuevo :  138  hospital B tiempo  17
# Llega paciente nuevo :  139  hospital A tiempo  17
# El paciente no tiene COVID :  133  hospital  B
# El paciente no tiene COVID :  135  hospital  A
# El paciente no tiene COVID :  137  hospital  B
# El paciente no tiene COVID :  138  hospital  B
# El paciente no tiene COVID :  139  hospital  A
# El paciente  106  en el hospital  A  espero  4  dias y fallece no hay camas
# El paciente  126  en el hospital  A  espero  1  dias y fallece no hay camas
# Llega paciente nuevo :  140  hospital A tiempo  18
# Llega paciente nuevo :  141  hospital B tiempo  18
# Llega paciente nuevo :  142  hospital B tiempo  18
# Llega paciente nuevo :  143  hospital B tiempo  18
# Llega paciente nuevo :  144  hospital A tiempo  18
# Llega paciente nuevo :  145  hospital B tiempo  18
# Llega paciente nuevo :  146  hospital B tiempo  18
# El paciente no tiene COVID :  140  hospital  A
# El paciente no tiene COVID :  141  hospital  B
# El paciente no tiene COVID :  146  hospital  B
# El paciente  113  en el hospital  A  espero  4  dias y fallece no hay camas
# El paciente  123  en el hospital  A  espero  3  dias y fallece no hay camas
# El paciente  127  en el hospital  B  espero  2  dias y fallece no hay camas
# Llega paciente nuevo :  147  hospital A tiempo  19
# Llega paciente nuevo :  148  hospital B tiempo  19
# Llega paciente nuevo :  149  hospital A tiempo  19
# Llega paciente nuevo :  150  hospital B tiempo  19
# Llega paciente nuevo :  151  hospital A tiempo  19
# Llega paciente nuevo :  152  hospital A tiempo  19
# Llega paciente nuevo :  153  hospital A tiempo  19
# El paciente no tiene COVID :  148  hospital  B
# El paciente no tiene COVID :  151  hospital  A
# El paciente no tiene COVID :  152  hospital  A
# El paciente  114  en el hospital  A  espero  5  dias y fallece no hay camas
# El paciente  121  en el hospital  A  espero  4  dias y fallece no hay camas
# El paciente  122  en el hospital  A  espero  4  dias y fallece no hay camas
# El paciente  124  en el hospital  B  espero  4  dias y fallece no hay camas
# El paciente  128  en el hospital  B  espero  3  dias y fallece no hay camas
# El paciente  129  en el hospital  A  espero  3  dias y fallece no hay camas
# El paciente  136  en el hospital  B  espero  2  dias y fallece no hay camas
# El paciente  144  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  145  en el hospital  B  espero  1  dias y fallece no hay camas
# Resultados pacientes :
# Recuperados:
# {5: 1, 6: 2, 8: 1, 9: 1, 10: 2, 11: 2, 12: 1, 13: 2, 14: 2, 16: 1}
# Fallecidos:
# {2: 1, 3: 1, 4: 2, 5: 6, 6: 4, 7: 1, 8: 2, 9: 4, 10: 3, 12: 4, 13: 3, 14: 3, 15: 4, 16: 2, 17: 2, 18: 3, 19: 9}
